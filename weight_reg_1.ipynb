# %% [markdown]
# <a href="https://colab.research.google.com/github/stalin99835/DUDL/blob/main/weight_reg_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch.nn as nn
import torch as torch
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from torch.utils.data import DataLoader

# %%
import seaborn as sns
iris = sns.load_dataset("iris")

# %%
data = torch.tensor(iris[iris.columns[0:4]].values).float()
print(data)
labels = torch.zeros(len(data),dtype=torch.long)
labels[iris.species=='setosa'] = 0
labels[iris.species=='versicolor'] = 1
labels[iris.species=='virginica'] = 2
# Out:
# tensor([[5.1000, 3.5000, 1.4000, 0.2000],
#         [4.9000, 3.0000, 1.4000, 0.2000],
#         [4.7000, 3.2000, 1.3000, 0.2000],
#         [4.6000, 3.1000, 1.5000, 0.2000],
#         [5.0000, 3.6000, 1.4000, 0.2000],
#         [5.4000, 3.9000, 1.7000, 0.4000],
#         [4.6000, 3.4000, 1.4000, 0.3000],
#         [5.0000, 3.4000, 1.5000, 0.2000],
#         [4.4000, 2.9000, 1.4000, 0.2000],
#         [4.9000, 3.1000, 1.5000, 0.1000],
#         [5.4000, 3.7000, 1.5000, 0.2000],
#         [4.8000, 3.4000, 1.6000, 0.2000],
#         [4.8000, 3.0000, 1.4000, 0.1000],
#         [4.3000, 3.0000, 1.1000, 0.1000],
#         [5.8000, 4.0000, 1.2000, 0.2000],
#         [5.7000, 4.4000, 1.5000, 0.4000],
#         [5.4000, 3.9000, 1.3000, 0.4000],
#         [5.1000, 3.5000, 1.4000, 0.3000],
#         [5.7000, 3.8000, 1.7000, 0.3000],
#         [5.1000, 3.8000, 1.5000, 0.3000],
#         [5.4000, 3.4000, 1.7000, 0.2000],
#         [5.1000, 3.7000, 1.5000, 0.4000],
# ...

# %%
train_data,test_data,train_labels,test_labels = train_test_split(data,labels,test_size=0.2)

train_dataDataset = torch.utils.data.TensorDataset(train_data,train_labels)
test_dataDataset = torch.utils.data.TensorDataset(test_data,test_labels)

train_dataloader = DataLoader(train_dataDataset,batch_size=64,shuffle=True,drop_last=True)
test_dataloader = DataLoader(test_dataDataset,batch_size=test_dataDataset.tensors[0].shape[0])

# %%
def CreateModel():
  model = nn.Sequential(
      nn.Linear(4,64),
      nn.ReLU(),
      nn.Linear(64,64),
      nn.ReLU(),
      nn.Linear(64,3)
  )

  lossfun= nn.CrossEntropyLoss()
  optimiser = torch.optim.SGD(model.parameters(),lr=0.001,weight_decay=L2lambda)

  return model,lossfun,optimiser

# %%
def trainTheModel():

  #initialise accuracy mtx
  trainAcc = []
  testAcc = []
  losses = []

  #loop over epochs
  for epochi in range(numepochs):
    #train test toggle

    #loop over training batches
    batchAcc = []
    batchLoss = []
    for X,y in train_dataloader:
      #forwrs pass
      yHat = ANNIris(X)
      loss = lossfun(yhat,y)

      #backprop
      optimiser.zero_grad()
      loss.backward()
      optimiser.step()

      #calc accuracyfor batch
      batchAcc.append(100*torch.mean((torch.mean((torch.argmax(yHat,axis=1)==y)).float()).item()))
      batchLoss.append(loss.item())

    #get aaverage accusracy
    trainAcc.append(np.mean(batchAcc))
    losses.append(np.mean(batchLoss))

    #test accuracy
    ANNIris.eval()
    X,y = next(iter(test_dataloader))
    Predlabels = torch.argmax(ANNIris(X),axis=1)
    testAcc.append(100*torch.mean((torch.mean((predlabels == y)).float()).item()))
    #toggle off test
    ANIris.train()

    return trainAcc,testAcc,losses
